# %% [markdown]
# # seaborn module
#
# - high level graphics package
#     - based on matplotlib
# - produces beautiful plots with little effort
# - [doc](http://seaborn.pydata.org/index.html)

# %%
# setup

import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# put plots in notebook
# %matplotlib inline
sns.__version__
# Out:
# '0.10.0'

# %% [markdown]
# # [distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html#seaborn.distplot)

# %%
sns.set()
x = np.random.randn(1000)
ax = sns.distplot(x)

# %% [markdown]
# # [jointplot](https://seaborn.pydata.org/search.html?q=jointplot&check_keywords=yes&area=default)

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

sns.jointplot(x="x", y="y", data=df);

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(df.x, df.y, ax=ax)
sns.rugplot(df.x, color="g", ax=ax)
sns.rugplot(df.y, vertical=True, ax=ax);

# %%
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=60, shade=True);

# %%
g = sns.jointplot(x="x", y="y", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %% [markdown]
# # [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html?highlight=pairplot)

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
np.random.seed(sum(map(ord, "regression")))
tips = sns.load_dataset("tips")
sns.regplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# # [lmplot](https://seaborn.pydata.org/generated/seaborn.lmplot.html?highlight=lmplot)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips,
           markers=["o", "x"], palette="Set1");

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");

# %%
np.random.seed(sum(map(ord, "categorical")))
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
# add some horz jitter to make it easier to distinish points

sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %% [markdown]
# # [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html?highlight=boxplot#seaborn.boxplot)

# %%
sns.boxplot(x="day", y="total_bill", hue="time", data=tips);

# %% [markdown]
# # [violinplot](https://seaborn.pydata.org/generated/seaborn.violinplot.html?highlight=violinplot#seaborn.violinplot)

# %%
sns.violinplot(x="total_bill", y="day", hue="time", data=tips);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips,
               split=True, inner="stick", palette="Set3");

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="w", alpha=.5);
